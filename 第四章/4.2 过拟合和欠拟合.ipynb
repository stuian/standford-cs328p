# %% [markdown]
# # 过拟合和欠拟合

# %% [markdown]
# ![QQ%E6%88%AA%E5%9B%BE20211112111852.png](attachment:QQ%E6%88%AA%E5%9B%BE20211112111852.png)

# %% [markdown]
# > 以考试为例

# %% [markdown]
# # 模型复杂度

# %% [markdown]
# - 参数多的一般也比参数少的模型复杂
# - 取值范围小的，比全范围取值的模型更简单（正则）

# %% [markdown]
# ## 模型复杂度的影响

# %% [markdown]
# ![QQ%E6%88%AA%E5%9B%BE20211112112630.png](attachment:QQ%E6%88%AA%E5%9B%BE20211112112630.png)

# %% [markdown]
# # 数据复杂度

# %% [markdown]
# - 样本数量
# - 数据结构（时间，空间）

# %% [markdown]
# # 数据与模型复杂度

# %% [markdown]
# ![QQ%E6%88%AA%E5%9B%BE20211112113451.png](attachment:QQ%E6%88%AA%E5%9B%BE20211112113451.png)

# %% [markdown]
# 不断累计数据，不断更新模型。

# %% [markdown]
# # 模型选择

# %% [markdown]
# 选择合适的模型，避免过拟合或欠拟合
#
# - 树模型
# - 神经网络
