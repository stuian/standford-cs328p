# %% [markdown]
# # 数据科学家的日常

# %% [markdown]
# ![QQ%E6%88%AA%E5%9B%BE20211019162142.png](attachment:QQ%E6%88%AA%E5%9B%BE20211019162142.png)

# %% [markdown]
# ## challenge

# %% [markdown]
# - 数据的数量和质量
# - 数据的质量
#     - 数据多样性（多方面），不偏性，公平性
# - 大数据存储，隐私和安全
