# %% [markdown]
# # 数据变换

# %% [markdown]
# ## Normalization

# %% [markdown]
# ![QQ%E6%88%AA%E5%9B%BE20211018210036.png](attachment:QQ%E6%88%AA%E5%9B%BE20211018210036.png)

# %% [markdown]
# ## 图片转换

# %% [markdown]
# - 机器学习对低像素的容忍度比较好
# - 下采样，降维来减少图片的大小

# %% [markdown]
# ## 视频转换

# %% [markdown]
# - 通常读取十秒以内
# - 视频存储和解码读取（GPU）
# - 采样关键帧

# %% [markdown]
# ## 文本转换

# %% [markdown]
# - 词根化/语法化，a word -> a common base form
# 如 is，are -> be; car,cars ->car
# - 分词

# %% [markdown]
# ![QQ%E6%88%AA%E5%9B%BE20211019150538.png](attachment:QQ%E6%88%AA%E5%9B%BE20211019150538.png)
