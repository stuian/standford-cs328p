# %% [markdown]
# # 特征工程

# %% [markdown]
# > 机器学习和深度学习的区别：机器学习手动构建特征，深度学习自动构架特征

# %% [markdown]
# ## tabular data features

# %% [markdown]
# ![QQ%E6%88%AA%E5%9B%BE20211019151319.png](attachment:QQ%E6%88%AA%E5%9B%BE20211019151319.png)

# %% [markdown]
# ## 文本数据特征

# %% [markdown]
# - bags of words
# - word embeddings(word2vec)
# 把一个词表示成一个向量，且包含一定的语义。相似的词其词向量也越相似。
# - 预训练语言模型（bert，GPT3)

# %% [markdown]
# ## 图片数据特征

# %% [markdown]
# - 手动特征（SIFT)
# - 将图片数据导入用已经训练好的模型，取倒数第二层的输出作为图片的特征，用于其他模型中。
