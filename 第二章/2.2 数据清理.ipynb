# %% [markdown]
# # 数据清理

# %% [markdown]
# > 对噪音比较多的数据进行清理

# %% [markdown]
# - 三种常见数据错误
#     - outlier detection（离群点，长尾：丢弃/手动修改重分配）
#     - rule-based detection
#     - pattern detection

# %% [markdown]
# ## 离群点检测

# %% [markdown]
# ![QQ%E6%88%AA%E5%9B%BE20211018204359.png](attachment:QQ%E6%88%AA%E5%9B%BE20211018204359.png)

# %% [markdown]
# ## 基于规则的检测

# %% [markdown]
# > ID唯一；不能为空等等
#
# - functional dependencies: x->y （x指定对应唯一的y）
# - denial constraints

# %% [markdown]
# ## 基于模式的检测

# %% [markdown]
# - 语法
#     - eng->English
# - 语义
#     - 一个国家需要一个首都

# %% [markdown]
# ## 数据清理工具

# %% [markdown]
# - OpenRefine
# - Trifacta Wrangler
